# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('gender_classification_v7.csv')

# %%
df
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   long_hair                  5001 non-null   int64
#  1   forehead_width_cm          5001 non-null   float64
#  2   forehead_height_cm         5001 non-null   float64
#  3   nose_wide                  5001 non-null   int64
#  4   nose_long                  5001 non-null   int64
#  5   lips_thin                  5001 non-null   int64
#  6   distance_nose_to_lip_long  5001 non-null   int64
#  7   gender                     5001 non-null   object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 312.7+ KB

# %%
df.describe()
# Out:
#          long_hair  forehead_width_cm  forehead_height_cm    nose_wide  \
# count  5001.000000        5001.000000         5001.000000  5001.000000
# mean      0.869626          13.181484            5.946311     0.493901
# std       0.336748           1.107128            0.541268     0.500013
# min       0.000000          11.400000            5.100000     0.000000
# 25%       1.000000          12.200000            5.500000     0.000000
# 50%       1.000000          13.100000            5.900000     0.000000
# 75%       1.000000          14.000000            6.400000     1.000000
# max       1.000000          15.500000            7.100000     1.000000
#
#          nose_long    lips_thin  distance_nose_to_lip_long
# count  5001.000000  5001.000000                5001.000000
# mean      0.507898     0.493101                   0.498900
# std       0.499988     0.500002                   0.500049
# min       0.000000     0.000000                   0.000000
# ...

# %%
df.head(3)
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male

# %%
df.tail(3)
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
#       lips_thin  distance_nose_to_lip_long  gender
# 4998          0                          0  Female
# 4999          0                          0  Female
# 5000          1                          1    Male

# %%
from  sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df['gender']=le.fit_transform(df['gender'])

# %%
import Faris_Stats as fs

# %%
for i in df.columns:
    print(i)
    fs.cal_pr(df[i])
    print('-'*80)
# Out:
# long_hair
# Total Revenue 4349
# Total_count 5001
# Mean 0.869626074785043
# median 1.0
# minimum 0
# Maximum 1
# range 1
# variance 0.11337656483900946
# Standard deviation 0.3367143668437827
# Quartile 1 : 1.0
# quartile 3 : 1.0
# inter quartile range 0.0
# lower_whisker 1.0
# upper_whisker 1.0
# Skewness -2.1954873993038855
# kurtosis 2.8201649205021377
# --------------------------------------------------------------------------------
# forehead_width_cm
# Total Revenue 65920.6
# Total_count 5001
# Mean 13.18148370325935
# median 13.1
# minimum 11.4
# Maximum 15.5
# range 4.1
# variance 1.225487980588231
# Standard deviation 1.1070176062684058
# Quartile 1 : 12.2
# quartile 3 : 14.0
# inter quartile range 1.8000000000000007
# lower_whisker 9.499999999999998
# upper_whisker 16.700000000000003
# Skewness 0.24216884127602942
# kurtosis -0.930865697789264
# --------------------------------------------------------------------------------
# forehead_height_cm
# Total Revenue 29737.5
# ...

# %%
df.isnull().sum()
# Out:
# long_hair                    0
# forehead_width_cm            0
# forehead_height_cm           0
# nose_wide                    0
# nose_long                    0
# lips_thin                    0
# distance_nose_to_lip_long    0
# gender                       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['long_hair', 'forehead_width_cm', 'forehead_height_cm', 'nose_wide',
#        'nose_long', 'lips_thin', 'distance_nose_to_lip_long', 'gender'],
#       dtype='object')

# %%
sns.pairplot(df[['forehead_width_cm','forehead_height_cm']])

# %%
for i in df.drop(['forehead_width_cm','forehead_height_cm'],axis=1).columns:
    print(i)
    sns.countplot(data=df,x=i)
    plt.show()
# Out:
# long_hair
# nose_wide
# nose_long
# lips_thin
# distance_nose_to_lip_long
# gender

# %%
sns.heatmap(df.corr(),annot=True,vmin=-1,vmax=1,cmap='coolwarm')
plt.show()

# %%
X=df.drop('gender',axis=1)
y=df['gender']

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
X=ss.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=50)

# %%
len(X_train)
# Out:
# 4000

# %%
len(X_test)
# Out:
# 1001

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model=GaussianNB()
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_train_pred=model.predict(X_train)
y_test_pred=model.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_train,y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      1967
#            1       0.98      0.97      0.97      2033
#
#     accuracy                           0.97      4000
#    macro avg       0.97      0.97      0.97      4000
# weighted avg       0.97      0.97      0.97      4000

# %%
print(classification_report(y_test,y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       534
#            1       0.97      0.97      0.97       467
#
#     accuracy                           0.97      1001
#    macro avg       0.97      0.97      0.97      1001
# weighted avg       0.97      0.97      0.97      1001

# %%
print('long_hair')
long_hair=int(input('please enter the value here :'))

print('forehead_width_cm')
forehead_width_cm=int(input('please enter the value here'))

print('forehead_height_cm')
forehead_height_cm=int(input('please enter the value'))

print('nose_wide')
nose_wide=int(input('please enter the value here'))

print('nose_long')
nose_long=int(input('please enter the value here'))

print('lips_thin')
lips_thin=int(input('please enter the value here'))

print('distance_nose_to_lip_long')
distance_nose_to_lip_long=int(input('please enter the value here'))
print('-'*50)

user_input = np.array([long_hair,forehead_width_cm,forehead_height_cm,nose_wide,nose_long,lips_thin,distance_nose_to_lip_long]).reshape(1,-1)

if model.predict(user_input)==0:
    print('THE PREDICTION IS :FEMALE')
else:
    print('THE PREDICTION IS :MALE')
# Out:
# long_hair
# forehead_width_cm
# forehead_height_cm
# nose_wide
# nose_long
# lips_thin
# distance_nose_to_lip_long
# --------------------------------------------------
# THE PREDICTION IS :MALE
